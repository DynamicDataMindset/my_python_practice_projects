# %%
# !pip install bing-image-downloader

# %%
# !mkdir excavator

# %%
from bing_image_downloader import downloader
downloader.download("Bell Excavator", limit=100,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/Bell Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
# [Error]Invalid image, not saving https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
#
# [!] Issue getting: https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
# [!] Error:: Invalid image, not saving https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
#
# [%] Downloading Image #1 from http://blog.truckandtrailer.co.za/wp-content/uploads/2017/01/hx390e-bell-crawler-excavator.jpg
# [!] Issue getting: http://blog.truckandtrailer.co.za/wp-content/uploads/2017/01/hx390e-bell-crawler-excavator.jpg
# [!] Error:: <urlopen error timed out>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from bing_image_downloader import downloader
downloader.download("Bell Excavator", limit=100,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/Bell Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
# [Error]Invalid image, not saving https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
#
# [!] Issue getting: https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
# [!] Error:: Invalid image, not saving https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
#
# [%] Downloading Image #1 from http://blog.truckandtrailer.co.za/wp-content/uploads/2017/01/hx390e-bell-crawler-excavator.jpg
# [!] Issue getting: http://blog.truckandtrailer.co.za/wp-content/uploads/2017/01/hx390e-bell-crawler-excavator.jpg
# [!] Error:: <urlopen error timed out>
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Bell Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 27 Images on Page 1606.
#
# ...
#
#
#
# [!!]Indexing page: 1607
#
# [%] Indexed 26 Images on Page 1607.
#
# ...
#
#
#
# [!!]Indexing page: 1608
#
# [%] Indexed 27 Images on Page 1608.
#
# ...
#
#
#
# [!!]Indexing page: 1609
#
# [%] Indexed 26 Images on Page 1609.
#
# ...
#
#
#
# [!!]Indexing page: 1610
#
# [%] Indexed 26 Images on Page 1610.
#
# ...
#
#
#
# [!!]Indexing page: 1611
#
# [%] Indexed 26 Images on Page 1611.
#
# ...
#
#
#
# [!!]Indexing page: 1612
#
# [%] Indexed 27 Images on Page 1612.
#
# ...
#
#
#
# [!!]Indexing page: 1613
#
# [%] Indexed 26 Images on Page 1613.
#
# ...
#
#
#
# [!!]Indexing page: 1614
#
# [%] Indexed 26 Images on Page 1614.
#
# ...
#
#
#
# [!!]Indexing page: 1615
#
# [%] Indexed 26 Images on Page 1615.
#
# ...
#
#
#
# [!!]Indexing page: 1616
#
# [%] Indexed 18 Images on Page 1616.
#
# ...
#
#
#
# [!!]Indexing page: 1617
#
# [%] Indexed 27 Images on Page 1617.
#
# ...
#
#
#
# [!!]Indexing page: 1618
#
# [%] Indexed 27 Images on Page 1618.
#
# ...
#
#
#
# ...

# %%
import shutil

# %%
shutil.make_archive('excavator', 'zip', 'excavator')
# Out:
# '/content/excavator.zip'

# %%
from google.colab import files

# %%
files.download('excavator.zip')

# %%
from bing_image_downloader import downloader
downloader.download("CAT Excavator", limit=100,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/CAT Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://s7d2.scene7.com/is/image/Caterpillar/CM20211215-e14a2-089cd
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://s7d2.scene7.com/is/image/Caterpillar/CM20190621-f2871-02b83
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://s7d2.scene7.com/is/image/Caterpillar/CM20181204-39200-36759
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://s7d2.scene7.com/is/image/Caterpillar/CM20201106-ace30-1b4ef
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://bihmequipment.com/wp-content/uploads/Excavators-336EL-1.jpg
# [!] Issue getting: http://bihmequipment.com/wp-content/uploads/Excavators-336EL-1.jpg
# [!] Error:: <urlopen error [Errno -3] Temporary failure in name resolution>
# [%] Downloading Image #5 from https://s7d2.scene7.com/is/image/Caterpillar/CM20170524-08734-27507
# ...

# %%
from bing_image_downloader import downloader
downloader.download("CAT Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Downloading Image #96 from https://www.heavyquipmag.com/wp-content/uploads/2021/02/CAT-1024x684.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #97 from https://www.lectura-specs.com/models/renamed/orig/crawler_excavators-349_e_l-caterpillar.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://www.equipmentjournal.com/wp-content/uploads/2021/07/Cat-303-CR-MHEX-CM20210517-82b21-10af4-1-scaled.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ...
#
# [%] Downloading Image #99 from https://s7d2.scene7.com/is/image/Caterpillar/CM20180619-56240-08077
# [%] File Downloaded !
#
# [%] Downloading Image #100 from https://wallpapercave.com/wp/wp5571302.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ...
#
# [%] Downloading Image #101 from https://www.ivtinternational.com/wp-content/uploads/2019/12/cat-1.jpeg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("volvo Excavators", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 369
#
# [%] Indexed 34 Images on Page 369.
#
# ...
#
# [%] Downloading Image #371 from https://i.ebayimg.com/images/g/utkAAOSw09xm0Nc0/s-l500.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #372 from https://media.sandhills.com/img.axd?id=9005028043&amp;wid=4326179343&amp;rwl=False&amp;p=&amp;ext=&amp;w=350&amp;h=220&amp;t=&amp;lp=&amp;c=True&amp;wt=False&amp;sz=Max&amp;rt=0&amp;checksum=CIcZyI3IfxE52nAM%2bMcdTHDQkbyAMB6vdNPxAl8XH%2f4%3d
# [!] Issue getting: https://media.sandhills.com/img.axd?id=9005028043&amp;wid=4326179343&amp;rwl=False&amp;p=&amp;ext=&amp;w=350&amp;h=220&amp;t=&amp;lp=&amp;c=True&amp;wt=False&amp;sz=Max&amp;rt=0&amp;checksum=CIcZyI3IfxE52nAM%2bMcdTHDQkbyAMB6vdNPxAl8XH%2f4%3d
# [!] Error:: HTTP Error 400: Bad Request
#
#
# [!!]Indexing page: 370
#
# [%] Indexed 34 Images on Page 370.
#
# ...
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("JCB Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Downloading Image #423 from https://www.heydownloads.com/wp-content/uploads/2020/09/JCB-2cx-Backhoe-Loader-Service-manual-PDF-9803-7100-1-1000x691.png
# [%] File Downloaded !
#
# [%] Downloading Image #424 from https://www.picclickimg.com/gRoAAOSwH~5kWf8X/New-Pressure-Switch-Sensor-332J0671-For-Excavator-JCB.webp
# [%] File Downloaded !
#
# [%] Downloading Image #425 from https://777parts.net/repository/600x/jcb/1d/095490.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #426 from https://www.picclickimg.com/MzkAAOSwocJmkP6L/For-Jcb-Backhoe-Forward-Reverse-Column.webp
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 422
#
# [%] Indexed 35 Images on Page 422.
#
# ...
#
# [%] Downloading Image #427 from https://www.mascus.ie/_next/image?url=https%3A%2F%2Fst.mascus.com%2Fimagetilewm%2Fproduct%2F93a016f6%2Fjcb-19-c-1-ny-0-99-ranta-tiltf%2C668fe6a2.jpg&amp;w=3840&amp;q=75
# ...

# %%
from bing_image_downloader import downloader
downloader.download("KOMATSU Excavator", limit=1000,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/KOMATSU Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.komatsuamerica.com/-/media/2017-redesign/equipment-images/excavators/excavators-mid-size/pc210lc-11_1.png?h=768&amp;w=1024&amp;la=en&amp;hash=5FB4E83B6386CD159B96B810118D8ED8A34FDE3E
# [!] Issue getting: https://www.komatsuamerica.com/-/media/2017-redesign/equipment-images/excavators/excavators-mid-size/pc210lc-11_1.png?h=768&amp;w=1024&amp;la=en&amp;hash=5FB4E83B6386CD159B96B810118D8ED8A34FDE3E
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://im-mining.com/site/wp-content/uploads/2021/04/Komatsu-PC5500-11-image-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.lectura-specs.com/models/renamed/orig/crawler-excavators-pc138us-11-komatsu(1).jpg
# [%] File Downloaded !
#
# ...

# %%
files.download('excavator.zip')

# %%
shutil.make_archive('excavator', 'zip', 'excavator')
# Out:
# '/content/excavator.zip'

# %%
files.download('excavator.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-4a3d667b96da> in <cell line: 1>()
# ----> 1 files.download('excavator.zip')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: excavator.zip

# %%
from google.colab import files

# %%
files.download('excavator.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-4a3d667b96da> in <cell line: 1>()
# ----> 1 files.download('excavator.zip')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: excavator.zip

# %%
files.download('excavator.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-4a3d667b96da> in <cell line: 1>()
# ----> 1 files.download('excavator.zip')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: excavator.zip

# %%
import shutil

# %%
shutil.make_archive('excavator', 'zip', 'excavator')
# Out:
# '/content/excavator.zip'

# %%
from google.colab import files

# %%
files.download('excavator.zip')

# %%
from bing_image_downloader import downloader
downloader.download("sandvik Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [!!]Indexing page: 166
#
# [%] Indexed 35 Images on Page 166.
#
# ...
#
# [%] Downloading Image #164 from https://www.plantandequipment.news/wp-content/uploads/2022/11/1787-sandvik-cover-imgs.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 167
#
# [%] Indexed 35 Images on Page 167.
#
# ...
#
# [%] Downloading Image #165 from https://mcdowellequipment.com/wp-content/uploads/IMG_20181127_083202735.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 168
#
# [%] Indexed 35 Images on Page 168.
#
# ...
#
#
#
# [!!]Indexing page: 169
#
# [%] Indexed 35 Images on Page 169.
#
# ...
#
# [%] Downloading Image #166 from http://scandasia.com/wp-content/uploads/2014/01/sandvik_cn.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #167 from https://i.ytimg.com/vi/z47xq8GHNXM/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 170
#
# [%] Indexed 35 Images on Page 170.
#
# ...
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("hitachi Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
#
# [%] Downloading Image #218 from https://st.mascus.com/image/product/large/37b82246/hitachi-zx85usb,2a5ddfed.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #219 from https://www.viequipmentltd.com/wp-content/uploads/2014/09/DSC_7346-1024x683.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 213
#
# [%] Indexed 35 Images on Page 213.
#
# ...
#
#
#
# [!!]Indexing page: 214
#
# [%] Indexed 35 Images on Page 214.
#
# ...
#
# [%] Downloading Image #220 from https://ramequipment.com.au/wp-content/uploads/2018/11/ZX85USB-5_Hitachi_Medium_Excavator_Photo_5_hi-scaled.jpg
# [Error]Invalid image, not saving https://ramequipment.com.au/wp-content/uploads/2018/11/ZX85USB-5_Hitachi_Medium_Excavator_Photo_5_hi-scaled.jpg
#
# [!] Issue getting: https://ramequipment.com.au/wp-content/uploads/2018/11/ZX85USB-5_Hitachi_Medium_Excavator_Photo_5_hi-scaled.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("john deer Excavator", limit=100,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/john deer Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://blog.rockanddirt.com/wp-content/uploads/2016/06/JD_670G_4.jpg
# [!] Issue getting: http://blog.rockanddirt.com/wp-content/uploads/2016/06/JD_670G_4.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #1 from https://www.equipmentworld.com/wp-content/uploads/sites/2/2016/06/JD_670G_3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.koenigequipment.com/sites/default/files/CCE_26G_Dec21.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://blog.rockanddirt.com/wp-content/uploads/2014/12/300glc-1-large.png
# [!] Issue getting: http://blog.rockanddirt.com/wp-content/uploads/2014/12/300glc-1-large.png
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #3 from https://blog.machinefinder.com/wp-content/uploads/2016/01/John-Deere-210G-LC-Excavator.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("john deer Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Downloading Image #157 from https://www.quarrymagazine.com/wp-content/uploads/2020/08/RDO-John-Deere-Excavator-Shoot-72.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 69
#
# [%] Indexed 35 Images on Page 69.
#
# ...
#
#
#
# [!!]Indexing page: 70
#
# [%] Indexed 35 Images on Page 70.
#
# ...
#
#
#
# [!!]Indexing page: 71
#
# [%] Indexed 35 Images on Page 71.
#
# ...
#
#
#
# [!!]Indexing page: 72
#
# [%] Indexed 35 Images on Page 72.
#
# ...
#
# [%] Downloading Image #158 from https://www.deere.com/assets/images/common/products/excavators/75g/75g_excavator_r4a037881_rrd_1366x788_large_0571f1313d1158ae937a6f2e05317387aba07684.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #159 from https://www.agprocompanies.com/webres/File/Construction/60G.png
# [%] File Downloaded !
#
# [%] Downloading Image #160 from https://media.baumpub.com/files/slides/locale_image/full/0108/26764_en_424da_29333_john-deere-870glc-excavator-1.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("manito Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 35 Images on Page 170.
#
# ...
#
# [%] Downloading Image #258 from http://www.boles-hire.ie/assets/img/mt1840.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 171
#
# [%] Indexed 35 Images on Page 171.
#
# ...
#
# [%] Downloading Image #259 from https://www.heydownloads.com/wp-content/uploads/2023/03/Mustang-Manitou-170Z-NXT2-Compact-Excavator-Parts-Manual-50940299-SN-00701-and-up-1.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 172
#
# [%] Indexed 35 Images on Page 172.
#
# ...
#
# [%] Downloading Image #260 from https://www.heydownloads.com/wp-content/uploads/2023/03/Mustang-Manitou-800Z-Compact-Excavator-Parts-Manual-50940215-SN-00701-and-up-2-600x480.png
# [%] File Downloaded !
#
# [%] Downloading Image #261 from https://used-heavymachinery.com/wp-content/uploads/2022/02/Excavator-Hitachi-ZX210F-5G-2017-Mn-1-020222.jpeg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 173
#
# [%] Indexed 35 Images on Page 173.
#
# ...
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("hyundai Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Downloading Image #277 from https://www.traceyroad.com/wp-content/uploads/2023/03/HX250MH-product-image-PNG.png
# [%] File Downloaded !
#
# [%] Downloading Image #278 from http://twentywheels.com/imgs/a/a/k/w/c/hyundai_210_lc___9_excavator_5_lgw.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #279 from https://5.imimg.com/data5/SELLER/Default/2021/10/SD/PO/SL/7458478/hyundai-excavator-rental-services-1000x1000.jpg
# [Error]Invalid image, not saving https://5.imimg.com/data5/SELLER/Default/2021/10/SD/PO/SL/7458478/hyundai-excavator-rental-services-1000x1000.jpg
#
# [!] Issue getting: https://5.imimg.com/data5/SELLER/Default/2021/10/SD/PO/SL/7458478/hyundai-excavator-rental-services-1000x1000.jpg
# [!] Error:: Invalid image, not saving https://5.imimg.com/data5/SELLER/Default/2021/10/SD/PO/SL/7458478/hyundai-excavator-rental-services-1000x1000.jpg
#
# ...

# %%
import shutil

# %%
shutil.make_archive('excavator', 'zip', 'excavator')
# Out:
# '/content/excavator.zip'

# %%
from google.colab import files

# %%
files.download('excavator.zip')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a3d667b96da> in <cell line: 1>()
# ----> 1 files.download('excavator.zip')
#
# NameError: name 'files' is not defined

# %%
files.download('excavator.zip')
