# %%
# !pip install bing_image_downloader

# %%
# !mkdir Dumptrucks

# %%
from bing_image_downloader import downloader

# %%
downloader.download('JCB DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Downloading Image #701 from https://cdne-ar-prod-scus-001.azureedge.net/blob/images/auction-images%2F2024-09-04%2F4cf187f0-31b0-46d5-b3e8-29d3a961b4e8.jpg?preset=740x555
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 469
#
# [%] Indexed 35 Images on Page 469.
#
# ...
#
# [%] Downloading Image #702 from https://cdne-ar-prod-scus-001.azureedge.net/blob/images/auction-images%2F2024-09-04%2F3e903508-e26b-452f-b5c8-fd49201ec290.jpg?preset=740x555
# [%] File Downloaded !
#
# [%] Downloading Image #703 from https://cdne-ar-prod-scus-001.azureedge.net/blob/images/auction-images%2F2024-08-31%2Fc756ceee-a273-41c8-862c-a73fab01b7bb.jpg?preset=46x46
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 470
#
# [%] Indexed 35 Images on Page 470.
#
# ...
#
# [%] Downloading Image #704 from https://cdne-ar-prod-scus-001.azureedge.net/blob/images/auction-images%2F2024-09-03%2F392dfc79-a3c8-4ee9-a957-14373c74fdce.jpg?preset=46x46
# [%] File Downloaded !
# ...

# %%
downloader.download('sandvik DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [!!]Indexing page: 310
#
# [%] Indexed 35 Images on Page 310.
#
# ...
#
#
#
# [!!]Indexing page: 311
#
# [%] Indexed 35 Images on Page 311.
#
# ...
#
# [%] Downloading Image #338 from https://ecoplantsales.uk/wp-content/uploads/2020/03/d432a7c5-42ec-4dbf-afce-e43d8e016a9a-1-1024x768.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 312
#
# [%] Indexed 35 Images on Page 312.
#
# ...
#
# [%] Downloading Image #339 from https://image.chitra.live/api/v1/wps/5bbe1a9/449d2139-e92c-45d7-b772-e01acb2165f3/2/Sandvik-TH665B-5-1074x654.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 313
#
# [%] Indexed 35 Images on Page 313.
#
# ...
#
# [%] Downloading Image #340 from https://i.pinimg.com/originals/01/c9/df/01c9dfda4e9812c9753fdc389678dba0.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 314
#
# [%] Indexed 35 Images on Page 314.
#
# ...
#
# [%] Downloading Image #341 from https://www.engineerlive.com/sites/engineerlive/files/sandvik1.jpeg
# ...

# %%
downloader.download('hitachi DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] File Downloaded !
#
# [%] Downloading Image #405 from http://www.azomining.com/images/Equipments/EquipmentImage_384.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 332
#
# [%] Indexed 35 Images on Page 332.
#
# ...
#
#
#
# [!!]Indexing page: 333
#
# [%] Indexed 35 Images on Page 333.
#
# ...
#
# [%] Downloading Image #406 from https://i.pinimg.com/474x/d7/ea/7e/d7ea7ed0800baf39e25ff51d11817ece.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #407 from https://media.baumpub.com/files/slides/locale_image/full/0080/19770_en_ad675_30790_eh4000ac-3-cover-machine.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 334
#
# [%] Indexed 35 Images on Page 334.
#
# ...
#
# [%] Downloading Image #408 from https://im-mining.com/site/wp-content/uploads/2021/06/Truck_with_trolley.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 335
#
# [%] Indexed 35 Images on Page 335.
#
# ...
#
#
#
# [!!]Indexing page: 336
#
# ...

# %%
downloader.download('JOHN DEER DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a81bfb7c9f00> in <cell line: 1>()
# ----> 1 downloader.download('JOHN DEER DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
#
# NameError: name 'downloader' is not defined

# %%
downloader.download('JOHN DEER DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a81bfb7c9f00> in <cell line: 1>()
# ----> 1 downloader.download('JOHN DEER DUMPTRUCKS', limit=1000, output_dir='Dumptrucks')
#
# NameError: name 'downloader' is not defined
