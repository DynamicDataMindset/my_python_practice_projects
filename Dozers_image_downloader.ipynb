# %%
# !pip install bing_image_downloader

# %%
# !mkdir DOZERS

# %%
from bing_image_downloader import downloader

# %%
downloader.download('Bell dozers', limit=1000, output_dir='Dozers')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 26 Images on Page 865.
#
# ...
#
#
#
# [!!]Indexing page: 866
#
# [%] Indexed 28 Images on Page 866.
#
# ...
#
#
#
# [!!]Indexing page: 867
#
# [%] Indexed 26 Images on Page 867.
#
# ...
#
#
#
# [!!]Indexing page: 868
#
# [%] Indexed 28 Images on Page 868.
#
# ...
#
#
#
# [!!]Indexing page: 869
#
# [%] Indexed 26 Images on Page 869.
#
# ...
#
#
#
# [!!]Indexing page: 870
#
# [%] Indexed 28 Images on Page 870.
#
# ...
#
#
#
# [!!]Indexing page: 871
#
# [%] Indexed 2 Images on Page 871.
#
# ...
#
#
#
# [!!]Indexing page: 872
#
# [%] Indexed 28 Images on Page 872.
#
# ...
#
#
#
# [!!]Indexing page: 873
#
# [%] Indexed 26 Images on Page 873.
#
# ...
#
#
#
# [!!]Indexing page: 874
#
# [%] Indexed 28 Images on Page 874.
#
# ...
#
#
#
# [!!]Indexing page: 875
#
# [%] Indexed 28 Images on Page 875.
#
# ...
#
#
#
# [!!]Indexing page: 876
#
# [%] Indexed 28 Images on Page 876.
#
# ...
#
#
#
# [!!]Indexing page: 877
#
# [%] Indexed 28 Images on Page 877.
#
# ...
#
#
#
# [!!]Indexing page: 878
#
# ...

# %%
downloader.download('CAT dozers', limit=1000, output_dir='Dozers')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 4 Images on Page 608.
#
# ...
#
#
#
# [!!]Indexing page: 609
#
# [%] Indexed 4 Images on Page 609.
#
# ...
#
#
#
# [!!]Indexing page: 610
#
# [%] Indexed 8 Images on Page 610.
#
# ...
#
#
#
# [!!]Indexing page: 611
#
# [%] Indexed 4 Images on Page 611.
#
# ...
#
#
#
# [!!]Indexing page: 612
#
# [%] Indexed 4 Images on Page 612.
#
# ...
#
#
#
# [!!]Indexing page: 613
#
# [%] Indexed 34 Images on Page 613.
#
# ...
#
#
#
# [!!]Indexing page: 614
#
# [%] Indexed 4 Images on Page 614.
#
# ...
#
#
#
# [!!]Indexing page: 615
#
# [%] Indexed 8 Images on Page 615.
#
# ...
#
#
#
# [!!]Indexing page: 616
#
# [%] Indexed 4 Images on Page 616.
#
# ...
#
#
#
# [!!]Indexing page: 617
#
# [%] Indexed 8 Images on Page 617.
#
# ...
#
#
#
# [!!]Indexing page: 618
#
# [%] Indexed 8 Images on Page 618.
#
# ...
#
#
#
# [!!]Indexing page: 619
#
# [%] Indexed 34 Images on Page 619.
#
# ...
#
#
#
# [!!]Indexing page: 620
#
# [%] Indexed 8 Images on Page 620.
#
# ...
#
#
#
# [!!]Indexing page: 621
#
# ...

# %%
downloader.download('VOLVO dozers', limit=1000, output_dir='Dozers')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 1640
#
# [%] Indexed 3 Images on Page 1640.
#
# ...
#
#
#
# [!!]Indexing page: 1641
#
# [%] Indexed 3 Images on Page 1641.
#
# ...
#
#
#
# [!!]Indexing page: 1642
#
# [%] Indexed 3 Images on Page 1642.
#
# ...
#
#
#
# [!!]Indexing page: 1643
#
# [%] Indexed 4 Images on Page 1643.
#
# ...
#
#
#
# [!!]Indexing page: 1644
#
# [%] Indexed 1 Images on Page 1644.
#
# ...
#
#
#
# [!!]Indexing page: 1645
#
# [%] Indexed 1 Images on Page 1645.
#
# ...
#
#
#
# [!!]Indexing page: 1646
#
# [%] Indexed 4 Images on Page 1646.
#
# ...
#
#
#
# [!!]Indexing page: 1647
#
# [%] Indexed 3 Images on Page 1647.
#
# ...
#
#
#
# [!!]Indexing page: 1648
#
# [%] Indexed 4 Images on Page 1648.
#
# ...
#
#
#
# [!!]Indexing page: 1649
#
# [%] Indexed 4 Images on Page 1649.
#
# ...
#
#
#
# [!!]Indexing page: 1650
#
# [%] Indexed 4 Images on Page 1650.
#
# ...
#
#
#
# [!!]Indexing page: 1651
#
# [%] Indexed 5 Images on Page 1651.
#
# ...
#
#
#
# [!!]Indexing page: 1652
#
# [%] Indexed 3 Images on Page 1652.
# ...

# %%
downloader.download('JCB dozers', limit=1000, output_dir='Dozers')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 29 Images on Page 640.
#
# ...
#
#
#
# [!!]Indexing page: 641
#
# [%] Indexed 11 Images on Page 641.
#
# ...
#
#
#
# [!!]Indexing page: 642
#
# [%] Indexed 29 Images on Page 642.
#
# ...
#
#
#
# [!!]Indexing page: 643
#
# [%] Indexed 32 Images on Page 643.
#
# ...
#
#
#
# [!!]Indexing page: 644
#
# [%] Indexed 32 Images on Page 644.
#
# ...
#
#
#
# [!!]Indexing page: 645
#
# [%] Indexed 11 Images on Page 645.
#
# ...
#
#
#
# [!!]Indexing page: 646
#
# [%] Indexed 29 Images on Page 646.
#
# ...
#
#
#
# [!!]Indexing page: 647
#
# [%] Indexed 29 Images on Page 647.
#
# ...
#
#
#
# [!!]Indexing page: 648
#
# [%] Indexed 29 Images on Page 648.
#
# ...
#
#
#
# [!!]Indexing page: 649
#
# [%] Indexed 29 Images on Page 649.
#
# ...
#
#
#
# [!!]Indexing page: 650
#
# [%] Indexed 11 Images on Page 650.
#
# ...
#
#
#
# [!!]Indexing page: 651
#
# [%] Indexed 29 Images on Page 651.
#
# ...
#
#
#
# [!!]Indexing page: 652
#
# [%] Indexed 29 Images on Page 652.
#
# ...
#
#
#
# [!!]Indexing page: 653
#
# ...

# %% [markdown]
# downloader.download('KOMATSU dozers', limit=1000, output_dir='Dozers')

# %%
import shutil

# %%
shutil.make_archive('Dozers', 'zip', 'Dozers')
# Out:
# '/content/Dozers.zip'

# %%
from google.colab import files

# %%
files.download('Dozers.zip')

# %%
downloader.download('Bell Diesel bowzers', limit=1000, output_dir='Dieselbowzers')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ...
#
# [%] Downloading Image #471 from https://cfcagri.co.za/wp-content/uploads/2023/05/Diesel-Bowser.-600L.-Hand-Pump.-No-Registration-Documents.-R16000-plus-VAT-1024x920.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 307
#
# [%] Indexed 35 Images on Page 307.
#
# ...
#
# [%] Downloading Image #472 from https://eu.amcdn.co.za/farm-equipment/agricultural-trailers-fuel-bowsers-custom-1000-litre-diesel-bowser-1950-id-71345295.or.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 308
#
# [%] Indexed 35 Images on Page 308.
#
# ...
#
# [%] Downloading Image #473 from https://www.pmsmitkonstruksie.co.za/wp-content/uploads/2023/02/Diesel-Bowser3.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 309
#
# [%] Indexed 35 Images on Page 309.
#
# ...
#
# [%] Downloading Image #474 from https://i.pinimg.com/736x/a9/bf/34/a9bf34183d602ddffae598ba7efe585e.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 310
#
# ...

# %%
downloader.download('CAT Diesel bowzers', limit=1000, output_dir='Dieselbowzers')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 2694
#
# [%] Indexed 1 Images on Page 2694.
#
# ...
#
#
#
# [!!]Indexing page: 2695
#
# [%] Indexed 1 Images on Page 2695.
#
# ...
#
#
#
# [!!]Indexing page: 2696
#
# [%] Indexed 1 Images on Page 2696.
#
# ...
#
#
#
# [!!]Indexing page: 2697
#
# [%] Indexed 1 Images on Page 2697.
#
# ...
#
#
#
# [!!]Indexing page: 2698
#
# [%] Indexed 1 Images on Page 2698.
#
# ...
#
#
#
# [!!]Indexing page: 2699
#
# [%] Indexed 1 Images on Page 2699.
#
# ...
#
#
#
# [!!]Indexing page: 2700
#
# [%] Indexed 2 Images on Page 2700.
#
# ...
#
#
#
# [!!]Indexing page: 2701
#
# [%] Indexed 1 Images on Page 2701.
#
# ...
#
#
#
# [!!]Indexing page: 2702
#
# [%] Indexed 1 Images on Page 2702.
#
# ...
#
#
#
# [!!]Indexing page: 2703
#
# [%] Indexed 1 Images on Page 2703.
#
# ...
#
#
#
# [!!]Indexing page: 2704
#
# [%] Indexed 1 Images on Page 2704.
#
# ...
#
#
#
# [!!]Indexing page: 2705
#
# [%] Indexed 1 Images on Page 2705.
#
# ...
#
#
#
# [!!]Indexing page: 2706
#
# [%] Indexed 1 Images on Page 2706.
# ...

# %%
downloader.download('VOLVO Diesel bowzers', limit=1000, output_dir='Dieselbowzers')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 1389
#
# [%] Indexed 30 Images on Page 1389.
#
# ...
#
#
#
# [!!]Indexing page: 1390
#
# [%] Indexed 30 Images on Page 1390.
#
# ...
#
#
#
# [!!]Indexing page: 1391
#
# [%] Indexed 30 Images on Page 1391.
#
# ...
#
#
#
# [!!]Indexing page: 1392
#
# [%] Indexed 30 Images on Page 1392.
#
# ...
#
#
#
# [!!]Indexing page: 1393
#
# [%] Indexed 32 Images on Page 1393.
#
# ...
#
#
#
# [!!]Indexing page: 1394
#
# [%] Indexed 30 Images on Page 1394.
#
# ...
#
#
#
# [!!]Indexing page: 1395
#
# [%] Indexed 30 Images on Page 1395.
#
# ...
#
#
#
# [!!]Indexing page: 1396
#
# [%] Indexed 30 Images on Page 1396.
#
# ...
#
#
#
# [!!]Indexing page: 1397
#
# [%] Indexed 35 Images on Page 1397.
#
# ...
#
#
#
# [!!]Indexing page: 1398
#
# [%] Indexed 30 Images on Page 1398.
#
# ...
#
#
#
# [!!]Indexing page: 1399
#
# [%] Indexed 30 Images on Page 1399.
#
# ...
#
#
#
# [!!]Indexing page: 1400
#
# [%] Indexed 35 Images on Page 1400.
#
# ...
#
#
#
# [!!]Indexing page: 1401
#
# ...

# %%
import shutil

# %%
shutil.make_archive('Dieselbowzers','zip','Dieselbowzers')
# Out:
# '/content/Dieselbowzers.zip'

# %%
from google.colab import files

# %%
files.download('Dieselbowzers.zip')
