# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
downloader.download("Bell Excavator", limit=1000,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/Bell Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://blog.truckandtrailer.co.za/wp-content/uploads/2017/01/hx390e-bell-crawler-excavator.jpg
# [!] Issue getting: http://blog.truckandtrailer.co.za/wp-content/uploads/2017/01/hx390e-bell-crawler-excavator.jpg
# [!] Error:: <urlopen error timed out>
# [%] Downloading Image #1 from https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
# [Error]Invalid image, not saving https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
#
# [!] Issue getting: https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
# [!] Error:: Invalid image, not saving https://cdn-s3.abcauctions.co.zw/20200922075451wBzHLpgwTXso/20200922075451wBzHLpgwTXso-Zoom.jpg
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("CAT Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ...
#
# [%] Downloading Image #96 from https://eu.amcdn.co.za/machinery/caterpillar-excavators-320d-id-69162521.or.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ...
#
# [%] Downloading Image #97 from https://s7d2.scene7.com/is/image/Caterpillar/CM20180619-56240-08077
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://www.australianmining.com.au/wp-content/uploads/2020/09/Cat-395-Excavator-handles-fragmented-rock-scaled.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ...
#
# [%] Downloading Image #99 from https://wallpapercave.com/wp/wp5571302.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ...
#
# [%] Downloading Image #100 from https://s7d2.scene7.com/is/image/Caterpillar/CM20180730-38666-57716
# ...

# %%
from bing_image_downloader import downloader
downloader.download("VOLVO Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# [!!]Indexing page: 244
#
# [%] Indexed 35 Images on Page 244.
#
# ...
#
# [%] Downloading Image #278 from https://www.volvoce.com/-/media/volvoce/global/products/excavators/compact-excavators/benefits/volvo-benefits-compact-excavator-ecr25d-t4i-transport-configuration-2324x1200.jpg?v=1BksPw
# [%] File Downloaded !
#
# [%] Downloading Image #279 from https://vistapointe.net/images/volvo-excavator-wallpaper-3.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 245
#
# [%] Indexed 35 Images on Page 245.
#
# ...
#
# [%] Downloading Image #280 from https://image.made-in-china.com/2f0j00eMlcyaiWAtkS/Used-Volvo-Ec350-Excavator-Volvo-Excavator-Ec240-Volvo-Excavator-210-Volvo-Excavators-for-Sale.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 246
#
# [%] Indexed 35 Images on Page 246.
#
# ...
#
# [%] Downloading Image #281 from https://st.mascus.com/image/product/large/dathut/volvo-ew180e,217871077_1.jpg
# [%] File Downloaded !
#
#
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("JCB Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 24 Images on Page 704.
#
# ...
#
#
#
# [!!]Indexing page: 705
#
# [%] Indexed 24 Images on Page 705.
#
# ...
#
#
#
# [!!]Indexing page: 706
#
# [%] Indexed 24 Images on Page 706.
#
# ...
#
#
#
# [!!]Indexing page: 707
#
# [%] Indexed 24 Images on Page 707.
#
# ...
#
#
#
# [!!]Indexing page: 708
#
# [%] Indexed 24 Images on Page 708.
#
# ...
#
#
#
# [!!]Indexing page: 709
#
# [%] Indexed 24 Images on Page 709.
#
# ...
#
#
#
# [!!]Indexing page: 710
#
# [%] Indexed 24 Images on Page 710.
#
# ...
#
#
#
# [!!]Indexing page: 711
#
# [%] Indexed 24 Images on Page 711.
#
# ...
#
#
#
# [!!]Indexing page: 712
#
# [%] Indexed 24 Images on Page 712.
#
# ...
#
#
#
# [!!]Indexing page: 713
#
# [%] Indexed 24 Images on Page 713.
#
# ...
#
#
#
# [!!]Indexing page: 714
#
# [%] Indexed 24 Images on Page 714.
#
# ...
#
#
#
# [!!]Indexing page: 715
#
# [%] Indexed 24 Images on Page 715.
#
# ...
#
#
#
# [!!]Indexing page: 716
#
# [%] Indexed 24 Images on Page 716.
#
# ...
#
#
#
# [!!]Indexing page: 717
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("KOMATSU Excavator", limit=100,  output_dir='excavator')
# Out:
# [%] Downloading Images to /content/excavator/KOMATSU Excavator
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.komatsuamerica.com/-/media/2017-redesign/equipment-images/excavators/excavators-mid-size/pc210lc-11_1.png?h=768&amp;w=1024&amp;la=en&amp;hash=5FB4E83B6386CD159B96B810118D8ED8A34FDE3E
# [!] Issue getting: https://www.komatsuamerica.com/-/media/2017-redesign/equipment-images/excavators/excavators-mid-size/pc210lc-11_1.png?h=768&amp;w=1024&amp;la=en&amp;hash=5FB4E83B6386CD159B96B810118D8ED8A34FDE3E
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://im-mining.com/site/wp-content/uploads/2021/04/Komatsu-PC5500-11-image-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.lectura-specs.com/models/renamed/orig/crawler-excavators-pc138us-11-komatsu(1).jpg
# [%] File Downloaded !
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from bing_image_downloader import downloader
downloader.download("KOMATSU Excavator", limit=1000,  output_dir='excavator')
# Out:
# Streaming output truncated to the last 5000 lines.
# [!!]Indexing page: 428
#
# [%] Indexed 35 Images on Page 428.
#
# ...
#
#
#
# [!!]Indexing page: 429
#
# [%] Indexed 35 Images on Page 429.
#
# ...
#
# [%] Downloading Image #404 from https://st.mascus.com/image/product/large/f506ee5d/komatsu-wa100m-8,52f6dad7.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 430
#
# [%] Indexed 35 Images on Page 430.
#
# ...
#
# [%] Downloading Image #405 from https://assets.primecreative.com.au/imagegen/560/-/assets/momoads/2024/09/01/160528/cc25f3dedaa5dc2225b061e54375a6f9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #406 from https://s.alicdn.com/@sc04/kf/Hf8cfe7196c0247b5b3542f1da1959befF.jpg_720x720q50.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 431
#
# [%] Indexed 35 Images on Page 431.
#
# ...
#
# ...

# %%
import shutil

# %%
shutil.make_archive('excavator', 'zip', 'excavator')
# Out:
# '/content/excavator.zip'

# %%
from google.colab import files

# %%
files.download('excavator.zip')

# %%
from bing_image_downloader import downloader
downloader.download("BELL DOZERS", limit=1000,  output_dir='DOZERS')
# Out:
# [%] Downloading Images to /content/DOZERS/BELL DOZERS
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/55/54/58/555458c7cff43d53273ee4f04da21c49.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.lectura-specs.com/models/renamed/orig/bulldozers-d_85_ex_i_18-komatsu.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://fthmb.tqn.com/B3fBfXO0I_6bBqBY9NUp0-Z-q4o=/2048x1365/filters:fill(auto,1)/26860572325_941f549b1d_k-58efd5a75f9b582c4d5bb5d3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.britannica.com/42/124942-050-5057EA58/Bulldozer.jpg
# [Error]Invalid image, not saving https://cdn.britannica.com/42/124942-050-5057EA58/Bulldozer.jpg
#
# [!] Issue getting: https://cdn.britannica.com/42/124942-050-5057EA58/Bulldozer.jpg
# [!] Error:: Invalid image, not saving https://cdn.britannica.com/42/124942-050-5057EA58/Bulldozer.jpg
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("VOLVO DOZERS", limit=1000,  output_dir='DOZERS')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Indexed 26 Images on Page 559.
#
# ...
#
#
#
# [!!]Indexing page: 560
#
# [%] Indexed 26 Images on Page 560.
#
# ...
#
#
#
# [!!]Indexing page: 561
#
# [%] Indexed 26 Images on Page 561.
#
# ...
#
#
#
# [!!]Indexing page: 562
#
# [%] Indexed 25 Images on Page 562.
#
# ...
#
#
#
# [!!]Indexing page: 563
#
# [%] Indexed 25 Images on Page 563.
#
# ...
#
#
#
# [!!]Indexing page: 564
#
# [%] Indexed 25 Images on Page 564.
#
# ...
#
#
#
# [!!]Indexing page: 565
#
# [%] Indexed 26 Images on Page 565.
#
# ...
#
#
#
# [!!]Indexing page: 566
#
# [%] Indexed 26 Images on Page 566.
#
# ...
#
#
#
# [!!]Indexing page: 567
#
# [%] Indexed 26 Images on Page 567.
#
# ...
#
#
#
# [!!]Indexing page: 568
#
# [%] Indexed 25 Images on Page 568.
#
# ...
#
#
#
# [!!]Indexing page: 569
#
# [%] Indexed 26 Images on Page 569.
#
# ...
#
#
#
# [!!]Indexing page: 570
#
# [%] Indexed 26 Images on Page 570.
#
# ...
#
#
#
# [!!]Indexing page: 571
#
# [%] Indexed 26 Images on Page 571.
#
# ...
#
#
#
# [!!]Indexing page: 572
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("JCB DOZERS", limit=1000,  output_dir='DOZERS')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 12 Images on Page 449.
#
# ...
#
#
#
# [!!]Indexing page: 450
#
# [%] Indexed 12 Images on Page 450.
#
# ...
#
#
#
# [!!]Indexing page: 451
#
# [%] Indexed 13 Images on Page 451.
#
# ...
#
#
#
# [!!]Indexing page: 452
#
# [%] Indexed 12 Images on Page 452.
#
# ...
#
#
#
# [!!]Indexing page: 453
#
# [%] Indexed 12 Images on Page 453.
#
# ...
#
#
#
# [!!]Indexing page: 454
#
# [%] Indexed 12 Images on Page 454.
#
# ...
#
#
#
# [!!]Indexing page: 455
#
# [%] Indexed 13 Images on Page 455.
#
# ...
#
#
#
# [!!]Indexing page: 456
#
# [%] Indexed 12 Images on Page 456.
#
# ...
#
#
#
# [!!]Indexing page: 457
#
# [%] Indexed 12 Images on Page 457.
#
# ...
#
#
#
# [!!]Indexing page: 458
#
# [%] Indexed 13 Images on Page 458.
#
# ...
#
#
#
# [!!]Indexing page: 459
#
# [%] Indexed 13 Images on Page 459.
#
# ...
#
#
#
# [!!]Indexing page: 460
#
# [%] Indexed 12 Images on Page 460.
#
# ...
#
#
#
# [!!]Indexing page: 461
#
# [%] Indexed 13 Images on Page 461.
#
# ...
#
#
#
# [!!]Indexing page: 462
#
# ...
