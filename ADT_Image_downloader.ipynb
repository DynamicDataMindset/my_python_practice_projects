# %%
# !pip install bing_image_downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download('Dumptruck ADT hyundai', limit=1000, output_dir='Dumptruck')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 35 Images on Page 3064.
#
# ...
#
#
#
# [!!]Indexing page: 3065
#
# [%] Indexed 35 Images on Page 3065.
#
# ...
#
#
#
# [!!]Indexing page: 3066
#
# [%] Indexed 35 Images on Page 3066.
#
# ...
#
#
#
# [!!]Indexing page: 3067
#
# [%] Indexed 35 Images on Page 3067.
#
# ...
#
#
#
# [!!]Indexing page: 3068
#
# [%] Indexed 35 Images on Page 3068.
#
# ...
#
#
#
# [!!]Indexing page: 3069
#
# [%] Indexed 35 Images on Page 3069.
#
# ...
#
#
#
# [!!]Indexing page: 3070
#
# [%] Indexed 35 Images on Page 3070.
#
# ...
#
#
#
# [!!]Indexing page: 3071
#
# [%] Indexed 35 Images on Page 3071.
#
# ...
#
#
#
# [!!]Indexing page: 3072
#
# [%] Indexed 35 Images on Page 3072.
#
# ...
#
#
#
# [!!]Indexing page: 3073
#
# [%] Indexed 35 Images on Page 3073.
#
# ...
#
#
#
# [!!]Indexing page: 3074
#
# [%] Indexed 35 Images on Page 3074.
#
# ...
#
#
#
# [!!]Indexing page: 3075
#
# [%] Indexed 35 Images on Page 3075.
#
# ...
#
#
#
# [!!]Indexing page: 3076
#
# [%] Indexed 35 Images on Page 3076.
#
# ...
#
#
#
# ...

# %%
downloader.download('Dumptruck ADT hyundai', limit=1000, output_dir='Dumptruck')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95273312472f> in <cell line: 1>()
# ----> 1 downloader.download('Dumptruck ADT hyundai', limit=1000, output_dir='Dumptruck')
#
# NameError: name 'downloader' is not defined

# %%
# !pip install bing_image_downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download('Dumptruck ADT hyundai', limit=1000, output_dir='Dumptruck')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 241
#
# [%] Indexed 35 Images on Page 241.
#
# ...
#
#
#
# [!!]Indexing page: 242
#
# [%] Indexed 35 Images on Page 242.
#
# ...
#
# [%] Downloading Image #217 from https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEgSoihqQiw4BZT4TVyEEiqu4YyIa0_PyUFR1EXRcqHysVE7dCyW9n4vVC-TE_QC3hKS1hQ8BRwGwdMLRkdvbQtJoDtymHhX2ISdm7CWp2ZHhABFd35zj1Bcr9VdylipXlF5S_18j9xc4XMvD9I28negBrv0fkMO6SSbzsh_Ca5xzXduyiedmOajU6RHvA/s874/IMG_20220827_175409_986.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 243
#
# [%] Indexed 35 Images on Page 243.
#
# ...
#
# [%] Downloading Image #218 from https://gradewellgroup.co.uk/wp-content/uploads/2020/04/cat-730-dump-truck.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 244
#
# [%] Indexed 35 Images on Page 244.
#
# ...
#
#
#
# [!!]Indexing page: 245
#
# [%] Indexed 35 Images on Page 245.
#
# ...
#
# ...

# %%
import shutil

# %%
shutil.make_archive('Dumptruck', 'zip', 'Dumptruck')
# Out:
# '/content/Dumptruck.zip'

# %%
from google.colab import files

# %%
files.download('Dumptruck.zip')
