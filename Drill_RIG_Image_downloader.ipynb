# %%
# !pip install bing_image_downloader

# %%
# !mkdir DRILLRIG

# %%
from bing_image_downloader import downloader

# %%
downloader.download('JCV DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
# [!!]Indexing page: 35
#
# [%] Indexed 35 Images on Page 35.
#
# ...
#
# [%] Downloading Image #71 from https://www.jpnelson.com.sg/image/cache/catalog/Product/Boring Rigs/E041746/IMG_1816-1600x1200.jpg
# [!] Issue getting: https://www.jpnelson.com.sg/image/cache/catalog/Product/Boring Rigs/E041746/IMG_1816-1600x1200.jpg
# [!] Error:: URL can't contain control characters. '/image/cache/catalog/Product/Boring Rigs/E041746/IMG_1816-1600x1200.jpg' (found at least ' ')
# [%] Downloading Image #71 from https://beemanequipmentsales.com/wp-content/uploads/2022/12/1973-Gardner-Denver-15W-Drill-Rig6.jpg
# [Error]Invalid image, not saving https://beemanequipmentsales.com/wp-content/uploads/2022/12/1973-Gardner-Denver-15W-Drill-Rig6.jpg
#
# [!] Issue getting: https://beemanequipmentsales.com/wp-content/uploads/2022/12/1973-Gardner-Denver-15W-Drill-Rig6.jpg
# ...

# %%
downloader.download('KOMATSU DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 449
#
# [%] Indexed 35 Images on Page 449.
#
# ...
#
# [%] Downloading Image #370 from https://img.linemedia.com/img/s/construction-equipment-wheel-loader-Caterpillar-996H---1693810956901106060_big--23090409485412318300.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 450
#
# [%] Indexed 35 Images on Page 450.
#
# ...
#
# [%] Downloading Image #371 from https://img.linemedia.com/img/s/construction-equipment-bulldozer-CAT-D6M-LGP-SPYCHARKA-GaSIENNICOWA-2006-YEAR---1712217536588102916_common--24040410540286609300.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 451
#
# [%] Indexed 35 Images on Page 451.
#
# ...
#
#
#
# [!!]Indexing page: 452
#
# [%] Indexed 35 Images on Page 452.
#
# ...
#
# [%] Downloading Image #372 from https://img.linemedia.com/img/s/construction-equipment-bulldozer-Caterpillar-D9R---1626791967921517188_common--21072017361741989500.jpg
# [%] File Downloaded !
#
#
#
# ...

# %%
downloader.download('SANDVIK DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Indexed 35 Images on Page 261.
#
# ...
#
# [%] Downloading Image #205 from https://machineryline.info/img/s/construction-equipment-drilling-rig-Sandvik-Dino-DC400Ri---1689206967697243219_big--23071303092401687500.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 262
#
# [%] Indexed 35 Images on Page 262.
#
# ...
#
# [%] Downloading Image #206 from https://machineryline.info/img/s/construction-equipment-drilling-rig-Sandvik-DX800R---1696983155655163911_big--23101103123461769700.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 263
#
# [%] Indexed 35 Images on Page 263.
#
# ...
#
# [%] Downloading Image #207 from https://machineryline.info/img/s/construction-equipment-drilling-rig-Sandvik-RDX5-Drifter-NEW---1665585523945966994_big--22101217363319484400.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 264
#
# [%] Indexed 35 Images on Page 264.
#
# ...
#
# ...

# %%
downloader.download('HITACHI DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 5 Images on Page 1411.
#
# ...
#
#
#
# [!!]Indexing page: 1412
#
# [%] Indexed 5 Images on Page 1412.
#
# ...
#
#
#
# [!!]Indexing page: 1413
#
# [%] Indexed 5 Images on Page 1413.
#
# ...
#
#
#
# [!!]Indexing page: 1414
#
# [%] Indexed 5 Images on Page 1414.
#
# ...
#
#
#
# [!!]Indexing page: 1415
#
# [%] Indexed 5 Images on Page 1415.
#
# ...
#
#
#
# [!!]Indexing page: 1416
#
# [%] Indexed 5 Images on Page 1416.
#
# ...
#
#
#
# [!!]Indexing page: 1417
#
# [%] Indexed 5 Images on Page 1417.
#
# ...
#
#
#
# [!!]Indexing page: 1418
#
# [%] Indexed 5 Images on Page 1418.
#
# ...
#
#
#
# [!!]Indexing page: 1419
#
# [%] Indexed 5 Images on Page 1419.
#
# ...
#
#
#
# [!!]Indexing page: 1420
#
# [%] Indexed 5 Images on Page 1420.
#
# ...
#
#
#
# [!!]Indexing page: 1421
#
# [%] Indexed 5 Images on Page 1421.
#
# ...
#
#
#
# [!!]Indexing page: 1422
#
# [%] Indexed 5 Images on Page 1422.
#
# ...
#
#
#
# [!!]Indexing page: 1423
#
# [%] Indexed 5 Images on Page 1423.
#
# ...
#
#
#
# [!!]Indexing page: 1424
# ...

# %%
downloader.download('JOHN DEER DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Indexed 35 Images on Page 361.
#
# ...
#
#
#
# [!!]Indexing page: 362
#
# [%] Indexed 35 Images on Page 362.
#
# ...
#
#
#
# [!!]Indexing page: 363
#
# [%] Indexed 35 Images on Page 363.
#
# ...
#
# [%] Downloading Image #361 from https://i.ytimg.com/vi/mrjSh3s6Fnw/hq2.jpg?sqp=-oaymwEoCOADEOgC8quKqQMcGADwAQH4AbYIgAKAD4oCDAgAEAEYZSBbKEYwDw==&amp;rs=AOn4CLDwV2Y3TC7TYh8GxSxShC5WN_kA0Q
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 364
#
# [%] Indexed 35 Images on Page 364.
#
# ...
#
#
#
# [!!]Indexing page: 365
#
# [%] Indexed 35 Images on Page 365.
#
# ...
#
#
#
# [!!]Indexing page: 366
#
# [%] Indexed 35 Images on Page 366.
#
# ...
#
#
#
# [!!]Indexing page: 367
#
# [%] Indexed 35 Images on Page 367.
#
# ...
#
# [%] Downloading Image #362 from https://i.machinio.com/thumb/1q2d2qu/504767/ddf6/john-deere-vanbrunt-grain-drill.jpg
# [Error]Invalid image, not saving https://i.machinio.com/thumb/1q2d2qu/504767/ddf6/john-deere-vanbrunt-grain-drill.jpg
#
# ...

# %%
downloader.download('MANITO DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
#
# [%] Downloading Image #149 from https://image.made-in-china.com/2f0j00DUNqtLKrhWkM/Hxy-44tl-Spindle-Type-Crawler-Tower-Integrated-Core-Drill-Rig.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 137
#
# [%] Indexed 35 Images on Page 137.
#
# ...
#
# [%] Downloading Image #150 from https://drillingsupply.info/media/catalog/product/cache/1/image/1200x/040ec09b1e35df139433887a97daa66f/e/x/exploration-drilling-rig-26.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 138
#
# [%] Indexed 35 Images on Page 138.
#
# ...
#
# [%] Downloading Image #151 from https://www.drillingrigmachine.com/wp-content/uploads/2022/06/33.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 139
#
# [%] Indexed 35 Images on Page 139.
#
# ...
#
# [%] Downloading Image #152 from http://www.sinocoredrill.com/photo/ps11953879-professional_underground_diamond_core_drill_rigs_with_drilling_depth_1000m.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 140
#
# ...

# %%
downloader.download('HYUNDAI DRILL RIG', limit=1000, output_dir='DRILLRIG')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [!!]Indexing page: 292
#
# [%] Indexed 35 Images on Page 292.
#
# ...
#
# [%] Downloading Image #244 from http://www.everdigm-america.com/upload/201607/1ff0cb413ff658a9c4c7e6b2a5f2b96800c50e80.0.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 293
#
# [%] Indexed 35 Images on Page 293.
#
# ...
#
# [%] Downloading Image #245 from https://alashwalelectric.com/wp-content/uploads/2022/09/hyundai-drill05.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 294
#
# [%] Indexed 35 Images on Page 294.
#
# ...
#
# [%] Downloading Image #246 from http://www.sinocoredrill.com/photo/pl186041-hydx_6_full_hydraulic_drilling_rig.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 295
#
# [%] Indexed 35 Images on Page 295.
#
# ...
#
# [%] Downloading Image #247 from https://www.patrioteng.com/wp-content/uploads/2022/09/New-Drill-Rig-1440x810.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 296
#
# [%] Indexed 35 Images on Page 296.
#
# ...
#
# ...

# %%
import shutil

# %%
shutil.make_archive('DRILLRIG', 'zip', 'DRILLRIG')
# Out:
# '/content/DRILLRIG.zip'

# %%
from google.colab import files

# %%
files.download('DRILLRIG.zip')
