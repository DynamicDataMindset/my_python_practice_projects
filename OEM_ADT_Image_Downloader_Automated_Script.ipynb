# %%
# !pip install bing_image_downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download('BELL backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 142
#
# [%] Indexed 35 Images on Page 142.
#
# ...
#
# [%] Downloading Image #157 from https://sc04.alicdn.com/kf/Hfc3b833373e44c39b1c03fbfa8334717l/1028137966/Hfc3b833373e44c39b1c03fbfa8334717l.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 143
#
# [%] Indexed 35 Images on Page 143.
#
# ...
#
# [%] Downloading Image #158 from https://www.avesco-cat.com/fileadmin/_processed_/2/f/csm_Avesco_LT-1024_30282c7a70.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 144
#
# [%] Indexed 35 Images on Page 144.
#
# ...
#
#
#
# [!!]Indexing page: 145
#
# [%] Indexed 35 Images on Page 145.
#
# ...
#
# [%] Downloading Image #159 from https://i.ytimg.com/vi/WHsRhpAb_u0/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 146
#
# [%] Indexed 35 Images on Page 146.
#
# ...
#
# [%] Downloading Image #160 from https://i.machinio.com/medium/o5wnib/73846328.jpg
# ...

# %%
downloader.download('BELL backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ...
#
# [%] Downloading Image #52 from https://www.belltrucksamerica.com/wp-content/uploads/BTA-LubeCheckBanner205-1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ...
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ...
#
# [%] Downloading Image #53 from http://www.earthmoversmagazine.co.uk/wp-content/uploads/2018/04/DSC_1571-1-1024x682.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ...
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ...
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ...
#
# [%] Downloading Image #54 from https://ramequipment.com.au/wp-content/uploads/2023/04/Bell-ADT-website-1024x768.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('VOLVO backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# [%] Downloading Images to /content/BACKHOE/VOLVO backhoe ADT
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://sgcweb.s3.wasabisys.com/constructionequipment/s3fs-public/Volvo A45G_ADT cropped.jpg
# [!] Issue getting: https://sgcweb.s3.wasabisys.com/constructionequipment/s3fs-public/Volvo A45G_ADT cropped.jpg
# [!] Error:: URL can't contain control characters. '/constructionequipment/s3fs-public/Volvo A45G_ADT cropped.jpg' (found at least ' ')
# [%] Downloading Image #1 from https://agg-net.com/sites/default/files/images/articles/volvo-f-series-adt.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://go20location.ca/wp-content/uploads/2023/03/volvo-A30-Hors-route-30-tonnes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.gxcontractor.com/files/base/ebm/gxc/image/2013/05/volvo-adt1.png?auto=format,compress&amp;w=1050&amp;h=590&amp;fit=crop
# [%] File Downloaded !
#
# ...

# %%
downloader.download('JCV backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
#
#
#
# [!!]Indexing page: 766
#
# [%] Indexed 26 Images on Page 766.
#
# ...
#
#
#
# [!!]Indexing page: 767
#
# [%] Indexed 26 Images on Page 767.
#
# ...
#
#
#
# [!!]Indexing page: 768
#
# [%] Indexed 26 Images on Page 768.
#
# ...
#
#
#
# [!!]Indexing page: 769
#
# [%] Indexed 26 Images on Page 769.
#
# ...
#
#
#
# [!!]Indexing page: 770
#
# [%] Indexed 26 Images on Page 770.
#
# ...
#
#
#
# [!!]Indexing page: 771
#
# [%] Indexed 26 Images on Page 771.
#
# ...
#
#
#
# [!!]Indexing page: 772
#
# [%] Indexed 26 Images on Page 772.
#
# ...
#
#
#
# [!!]Indexing page: 773
#
# [%] Indexed 26 Images on Page 773.
#
# ...
#
#
#
# [!!]Indexing page: 774
#
# [%] Indexed 26 Images on Page 774.
#
# ...
#
#
#
# [!!]Indexing page: 775
#
# [%] Indexed 26 Images on Page 775.
#
# ...
#
#
#
# [!!]Indexing page: 776
#
# [%] Indexed 26 Images on Page 776.
#
# ...
#
#
#
# [!!]Indexing page: 777
#
# [%] Indexed 26 Images on Page 777.
#
# ...
#
#
#
# [!!]Indexing page: 778
#
# [%] Indexed 26 Images on Page 778.
#
# ...
#
#
#
# ...

# %%
downloader.download('SANDVIK backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [%] Downloading Image #44 from https://adamexmaszyny.pl/wp-content/uploads/2022/08/Sandvik_QA331_3.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 35 Images on Page 36.
#
# ...
#
# [%] Downloading Image #45 from https://mcdowellequipment.com/wp-content/uploads/IMG_20181127_083202735.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 35 Images on Page 37.
#
# ...
#
# [%] Downloading Image #46 from https://www.bmcdowell.com/media/djcatalog2/images/item/27/sandvik-lh514-underground-loader-b10-281_f.jpg
# [!] Issue getting: https://www.bmcdowell.com/media/djcatalog2/images/item/27/sandvik-lh514-underground-loader-b10-281_f.jpg
# [!] Error:: Remote end closed connection without response
#
#
# [!!]Indexing page: 38
#
# [%] Indexed 35 Images on Page 38.
#
# ...
#
# [%] Downloading Image #46 from https://europorssi.com/wp-content/uploads/2022/09/sandvik-1140x760.jpg
# [%] File Downloaded !
#
#
#
# ...

# %%
downloader.download('MANITO backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [!!]Indexing page: 228
#
# [%] Indexed 35 Images on Page 228.
#
# ...
#
#
#
# [!!]Indexing page: 229
#
# [%] Indexed 35 Images on Page 229.
#
# ...
#
#
#
# [!!]Indexing page: 230
#
# [%] Indexed 35 Images on Page 230.
#
# ...
#
#
#
# [!!]Indexing page: 231
#
# [%] Indexed 35 Images on Page 231.
#
# ...
#
#
#
# [!!]Indexing page: 232
#
# [%] Indexed 35 Images on Page 232.
#
# ...
#
# [%] Downloading Image #264 from https://5.imimg.com/data5/SELLER/PDFImage/2023/11/360571982/DX/IF/FP/23060463/manitou-backhoe-loader-mbl-745-s-1000x1000.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 233
#
# [%] Indexed 35 Images on Page 233.
#
# ...
#
#
#
# [!!]Indexing page: 234
#
# [%] Indexed 35 Images on Page 234.
#
# ...
#
#
#
# [!!]Indexing page: 235
#
# [%] Indexed 35 Images on Page 235.
#
# ...
#
#
#
# [!!]Indexing page: 236
#
# [%] Indexed 35 Images on Page 236.
#
# ...
#
# [%] Downloading Image #265 from https://fulcrum.ug/wp-content/uploads/2017/08/C10403273.jpg
# ...

# %%
downloader.download('HYUNDAI backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 35 Images on Page 228.
#
# ...
#
# [%] Downloading Image #197 from https://img.constructionequipment.com/files/base/ebm/constructionequipment/image/2022/06/1654723006165-doosan_adt.png?auto=format,compress&amp;fit=fill&amp;fill=blur&amp;w=1200&amp;h=630
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 229
#
# [%] Indexed 35 Images on Page 229.
#
# ...
#
# [%] Downloading Image #198 from https://img.constructionequipment.com/files/base/ebm/constructionequipment/image/2023/03/CASE_Utility_Plus_Backhoe_Loader_3.640b47e6f1c31.png?auto=format,compress&amp;fit=crop&amp;h=278&amp;w=500&amp;q=45
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 230
#
# [%] Indexed 35 Images on Page 230.
#
# ...
#
# [%] Downloading Image #199 from http://www.hydraulicbreakerhammer.com/photo/pl20589249-high_efficiency_backhoe_plate_compactor_for_hyundai_r220_r250_excavator.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 231
#
# ...

# %%
downloader.download('HITACHI backhoe ADT', limit=1000, output_dir='BACKHOE')
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 104
#
# [%] Indexed 35 Images on Page 104.
#
# ...
#
#
#
# [!!]Indexing page: 105
#
# [%] Indexed 35 Images on Page 105.
#
# ...
#
# [%] Downloading Image #106 from https://i.ytimg.com/vi/L3fJyVTJS8Y/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 106
#
# [%] Indexed 35 Images on Page 106.
#
# ...
#
# [%] Downloading Image #107 from http://srv888.weebly.com/uploads/5/3/5/8/53588981/_4582850_orig.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 107
#
# [%] Indexed 35 Images on Page 107.
#
# ...
#
# [%] Downloading Image #108 from https://5.imimg.com/data5/SELLER/Default/2023/3/KI/MI/GG/54614934/tata-hitachi-th-76-backhoe-loader-1000x1000.jpeg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 108
#
# [%] Indexed 35 Images on Page 108.
#
# ...
#
# [%] Downloading Image #109 from https://photo.static-viamobilis.com/2/1/2979992-foto-retroexcavadora.jpg
# [%] File Downloaded !
#
#
#
# ...

# %%
import shutil
shutil.make_archive('BACKHOE','zip','BACKHOE')
from google.colab import files
files.download('BACKHOE.zip')
